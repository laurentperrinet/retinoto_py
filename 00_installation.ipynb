# %% [markdown]
# - author: John Doe
# - date: 2018-05-11
# - category: pyhton
# - tags: pip

# %% [markdown]
# # Installation
#
# 1. create a venv
#
# ````
# python3 -m venv .venv
#
# ````
#
# 2. activate it:
#
# ````
# source .venv/bin/activate
#
# ````
#
# 3. install libraries :

# %%
# %pip install -U -r requirements.txt
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (25.3)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (4.12.0.88)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Collecting numpy (from -r requirements.txt (line 7))
#   Using cached numpy-2.3.5-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: numexpr in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (2.14.1)
# Requirement already satisfied: imageio in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (2.37.2)
# Requirement already satisfied: nltk in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (3.9.2)
# Requirement already satisfied: torch in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (2.2.2)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (0.17.2)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (7.1.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (8.1.8)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (1.1.1)
# Requirement already satisfied: notebook in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (7.5.0)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (7.16.6)
# Requirement already satisfied: lmfit in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (1.3.4)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (2.3.3)
# Requirement already satisfied: pyarrow in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (22.0.0)
# Requirement already satisfied: scipy in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 21)) (1.16.3)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (1.7.2)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 23)) (0.13.2)
# Requirement already satisfied: optuna in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (4.6.0)
# Requirement already satisfied: optuna-dashboard in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 25)) (0.20.0)
# Requirement already satisfied: watermark in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 26)) (2.5.0)
# Requirement already satisfied: moviepy in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (2.2.1)
# Requirement already satisfied: imageio-ffmpeg in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 29)) (0.6.0)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 30)) (4.67.1)
# Requirement already satisfied: pytest in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 31)) (9.0.1)
# Requirement already satisfied: ruff in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 32)) (0.14.6)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (2.9.0.post0)
#   Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: click in ./.venv/lib/python3.12/site-packages (from nltk->-r requirements.txt (line 10)) (8.3.1)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from nltk->-r requirements.txt (line 10)) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.12/site-packages (from nltk->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 11)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 11)) (4.15.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 11)) (1.14.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 11)) (3.6)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch->-r requirements.txt (line 11)) (2025.10.0)
# Requirement already satisfied: appnope>=0.1.2 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (9.7.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.12/site-packages (from ipykernel->-r requirements.txt (line 13)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./.venv/lib/python3.12/site-packages (from ipywidgets->-r requirements.txt (line 14)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./.venv/lib/python3.12/site-packages (from ipywidgets->-r requirements.txt (line 14)) (3.0.16)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 15)) (6.6.3)
# Requirement already satisfied: jupyterlab in ./.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.12/site-packages (from notebook->-r requirements.txt (line 16)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in ./.venv/lib/python3.12/site-packages (from notebook->-r requirements.txt (line 16)) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.12/site-packages (from notebook->-r requirements.txt (line 16)) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 15)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 15)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 15)) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 15)) (80.9.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (0.16.0)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (4.25.1)
# Requirement already satisfied: requests>=2.31 in ./.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 17)) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in ./.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->-r requirements.txt (line 17)) (6.3.0)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in ./.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 17)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 17)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in ./.venv/lib/python3.12/site-packages (from nbconvert->-r requirements.txt (line 17)) (2.19.2)
# Requirement already satisfied: asteval>=1.0 in ./.venv/lib/python3.12/site-packages (from lmfit->-r requirements.txt (line 18)) (1.0.7)
# Requirement already satisfied: uncertainties>=3.2.2 in ./.venv/lib/python3.12/site-packages (from lmfit->-r requirements.txt (line 18)) (3.2.3)
# Requirement already satisfied: dill>=0.3.4 in ./.venv/lib/python3.12/site-packages (from lmfit->-r requirements.txt (line 18)) (0.4.0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 19)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 19)) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 22)) (3.6.0)
# Requirement already satisfied: alembic>=1.5.0 in ./.venv/lib/python3.12/site-packages (from optuna->-r requirements.txt (line 24)) (1.17.2)
# Requirement already satisfied: colorlog in ./.venv/lib/python3.12/site-packages (from optuna->-r requirements.txt (line 24)) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in ./.venv/lib/python3.12/site-packages (from optuna->-r requirements.txt (line 24)) (2.0.44)
# Requirement already satisfied: PyYAML in ./.venv/lib/python3.12/site-packages (from optuna->-r requirements.txt (line 24)) (6.0.3)
# Requirement already satisfied: bottle>=0.13.0 in ./.venv/lib/python3.12/site-packages (from optuna-dashboard->-r requirements.txt (line 25)) (0.13.4)
# Requirement already satisfied: importlib-metadata>=1.4 in ./.venv/lib/python3.12/site-packages (from watermark->-r requirements.txt (line 26)) (8.7.0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in ./.venv/lib/python3.12/site-packages (from moviepy->-r requirements.txt (line 27)) (5.2.1)
# Requirement already satisfied: proglog<=1.0.0 in ./.venv/lib/python3.12/site-packages (from moviepy->-r requirements.txt (line 27)) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in ./.venv/lib/python3.12/site-packages (from moviepy->-r requirements.txt (line 27)) (1.2.1)
# Requirement already satisfied: iniconfig>=1.0.1 in ./.venv/lib/python3.12/site-packages (from pytest->-r requirements.txt (line 31)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./.venv/lib/python3.12/site-packages (from pytest->-r requirements.txt (line 31)) (1.6.0)
# Requirement already satisfied: Mako in ./.venv/lib/python3.12/site-packages (from alembic>=1.5.0->optuna->-r requirements.txt (line 24)) (1.3.10)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (25.1.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->-r requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib-metadata>=1.4->watermark->-r requirements.txt (line 26)) (3.23.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in ./.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in ./.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (0.29.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 13)) (4.5.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (25.10.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 16)) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in ./.venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.12/site-packages (from sqlalchemy>=1.4.2->optuna->-r requirements.txt (line 24)) (3.2.4)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (3.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (2.0.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (2.23)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->-r requirements.txt (line 17)) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy->torch->-r requirements.txt (line 11)) (1.3.0)
# Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_x86_64.whl (6.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -e .
# Out:
# Obtaining file:///Users/laurentperrinet/app54_nextcloud/science/retinoto_py
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: typer in ./.venv/lib/python3.12/site-packages (from retinoto_py==20251122) (0.20.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.12/site-packages (from typer->retinoto_py==20251122) (8.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.12/site-packages (from typer->retinoto_py==20251122) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.12/site-packages (from typer->retinoto_py==20251122) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.12/site-packages (from typer->retinoto_py==20251122) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer->retinoto_py==20251122) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer->retinoto_py==20251122) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->retinoto_py==20251122) (0.1.2)
# Building wheels for collected packages: retinoto_py
#   Building editable for retinoto_py (pyproject.toml) ... done
#   Created wheel for retinoto_py: filename=retinoto_py-20251122-0.editable-py3-none-any.whl size=3006 sha256=75848c963287dff9963946826b671d2baa68228fb73584aa831d906b16c6c614
#   Stored in directory: /private/var/folders/3p/m0g52j9j69z3gj8ktpgg1dm00000gn/T/pip-ephem-wheel-cache-jvmg9h2d/wheels/4d/51/9b/d60894b7eb5109917e261f54a734a810c404a9b163eb475345
# Successfully built retinoto_py
# Installing collected packages: retinoto_py
#   Attempting uninstall: retinoto_py
#     Found existing installation: retinoto_py 20251122
#     Uninstalling retinoto_py-20251122:
#       Successfully uninstalled retinoto_py-20251122
# Successfully installed retinoto_py-20251122
# Note: you may need to restart the kernel to use updated packages.

# %%
from retinoto_py import Params
args = Params()
args
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/local/Cellar/python@3.12/3.12.12/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/usr/local/Cellar/python@3.12/3.12.12/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/usr/local/Cellar/python@3.12/3.12.12/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/3p/m0g52j9j69z3gj8ktpgg1dm00000gn/T/ipykernel_60278/4260938032.py", line 1, in <module>
#     from retinoto_py import Params
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/src/retinoto_py/__init__.py", line 15, in <module>
#     from .params import Params
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/src/retinoto_py/params.py", line 2, in <module>
#     from .utils import get_device, set_seed
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/src/retinoto_py/utils.py", line 1, in <module>
#     import torch
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/laurentperrinet/app54_nextcloud/science/retinoto_py/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# Welcome on macOS-15.7.2-x86_64-i386-64bit	 user laurentperrinet	Running on MPS device (Apple Silicon/MacOS)	 - macos_version = 15.7.2	 with device mps, pytorch==2.2.2
# Random seed 1998 has been set.
# Params(image_size=224, do_mask=False, do_fovea=False, rs_min=0.0, rs_max=-5.0, padding_mode='zeros', seed=1998, batch_size=80, num_workers=4, in_memory=True, model_name='resnet101', do_scratch=False, num_epochs=10, n_train_stop=40960, n_val_stop=5120, lr=0.001, delta1=0.05, delta2=0.0, weight_decay=0.003, label_smoothing=0.0001, shuffle=True, verbose=True)

# %% [markdown]
# 4. test the imports:

# %% [markdown]
# 5. ImageNet  Data set

# %% [markdown]
# Now import images from  the [ImageNet website](https://image-net.org/challenges/LSVRC/2010/2010-downloads.php) following the instructions for [`torchvision.datasets.ImageNet`](https://pytorch.org/vision/stable/generated/torchvision.datasets.ImageNet.html).
#
# Then gather the ``ILSVRC2012_img_train.tar`` and ``ILSVRC2012_img_val.tar`` files into the folder defined as the `DATAROOT` parameter in the `retinotopy.py` file and extract the archive (takes time!).

# %%
# uncomment to do that
# !cd data; sh extract_ILSVRC.sh  # extract ILSVRC2012 dataset

# %% [markdown]
# Note that we will use the localisation data from https://www.kaggle.com/c/imagenet-object-localization-challenge/data

# %% [markdown]
# ## Appendix: version of the libraries that were used

# %%
# %load_ext watermark
# %watermark -i -h -m -v -p numpy,torch,matplotlib  -r -g -b
# Out:
# Python implementation: CPython
# Python version       : 3.12.12
# IPython version      : 9.7.0
#
# numpy     : 2.2.6
# torch     : 2.2.2
# matplotlib: 3.10.7
#
# Compiler    : Clang 17.0.0 (clang-1700.0.13.3)
# OS          : Darwin
# Release     : 24.6.0
# Machine     : x86_64
# Processor   : i386
# CPU cores   : 36
# Architecture: 64bit
#
# Hostname: Ahsoka
#
# Git hash: bc0f13dd5d498de0f6ca86bf6c9cea03b4f2e05e
#
# Git repo: https://github.com/laurentperrinet/retinoto_py.git
#
# Git branch: main

# %% [markdown]
# Voilà !
