# %% [markdown]
# # Installation Guide
#
# 1. create a venv
#
# ````
# python3 -m venv .venv
#
# ````
#
# 2. activate it:
#
# ````
# source .venv/bin/activate
#
# ````
#
# 3. install libraries :

# %%
# %pip install -U -r requirements.txt
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.14/site-packages (from -r requirements.txt (line 4)) (26.1.1)
# Collecting multiprocessing (from -r requirements.txt (line 5))
#   Downloading multiprocessing-2.6.2.1.tar.gz (108 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [25 lines of output]
#       Traceback (most recent call last):
#         File "/Users/laurent/sdrive_cnrs/hot_from_git/Retinotopy_project/retinoto_py/.venv/lib/python3.14/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "/Users/laurent/sdrive_cnrs/hot_from_git/Retinotopy_project/retinoto_py/.venv/lib/python3.14/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/laurent/sdrive_cnrs/hot_from_git/Retinotopy_project/retinoto_py/.venv/lib/python3.14/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/private/var/folders/qt/n82pbkv93fjb7bpt0pj1992w0000gn/T/pip-build-env-oi_g72ze/overlay/lib/python3.14/site-packages/setuptools/build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/qt/n82pbkv93fjb7bpt0pj1992w0000gn/T/pip-build-env-oi_g72ze/overlay/lib/python3.14/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "/private/var/folders/qt/n82pbkv93fjb7bpt0pj1992w0000gn/T/pip-build-env-oi_g72ze/overlay/lib/python3.14/site-packages/setuptools/build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/qt/n82pbkv93fjb7bpt0pj1992w0000gn/T/pip-build-env-oi_g72ze/overlay/lib/python3.14/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 94
#           print 'Macros:'
#           ^^^^^^^^^^^^^^^
#       SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'multiprocessing' when getting requirements to build wheel
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -e .

# %% [markdown]
# 4. test the imports:

# %%
from retinoto_py import Params
args = Params()
args

# %% [markdown]
# 5. ImageNet  Data set

# %% [markdown]
# Now import images from  the [ImageNet website](https://image-net.org/challenges/LSVRC/2010/2010-downloads.php) following the instructions for [`torchvision.datasets.ImageNet`](https://pytorch.org/vision/stable/generated/torchvision.datasets.ImageNet.html).
#
# Then gather the ``ILSVRC2012_img_train.tar`` and ``ILSVRC2012_img_val.tar`` files into the folder defined as the `DATAROOT` parameter in the `retinotopy.py` file and extract the archive (takes time!).

# %%
# uncomment to do that
# !cd data; sh extract_ILSVRC.sh  # extract ILSVRC2012 dataset

# %% [markdown]
# 6. download models

# %%
# ----------------------------------------------------------------------
import os
import torchvision.models as models
# ----------------------------------------------------------------------
# Tell torchvision to use that folder
os.environ.setdefault('TORCH_HOME', str(args.data_cache))
models_to_download = [
    lambda: models.resnet18(weights=models.ResNet18_Weights.DEFAULT),
    lambda: models.resnet50(weights=models.ResNet50_Weights.DEFAULT),
    lambda: models.resnet101(weights=models.ResNet101_Weights.DEFAULT),
    lambda: models.convnext_tiny(weights=models.ConvNeXt_Tiny_Weights.IMAGENET1K_V1),
    lambda: models.convnext_small(weights=models.ConvNeXt_Small_Weights.IMAGENET1K_V1),
    lambda: models.convnext_base(weights=models.ConvNeXt_Base_Weights.IMAGENET1K_V1),
    lambda: models.convnext_large(weights=models.ConvNeXt_Large_Weights.IMAGENET1K_V1),
]

for factory in models_to_download:
    factory()            # triggers download into data_cache
print("[✔] All pretrained models cached in", args.data_cache)

# %% [markdown]
# Note that we will use the localisation data from https://www.kaggle.com/c/imagenet-object-localization-challenge/data

# %% [markdown]
# ## Appendix: version of the libraries that were used

# %%
# %load_ext watermark
# %watermark -i -h -m -v -p numpy,torch,matplotlib  -r -g -b

# %% [markdown]
# Voilà !
