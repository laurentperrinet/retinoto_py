# %% [markdown]
# Optimisation de l'entrainement pour `focus`
# This is the same function as used in `10_Transfer_learning_what_networks.ipynb`
# > ... TODO ... # TODO test without circular padding, with Adam, with no warmstart
#
#     model = torchvision.models.resnet18(weights=None)

# %% [markdown]
# # optimize meta-parameters

# %%
import dataclasses

# %%
# print_gpu_memory()

# print(path_save)
# %ls -l {path}*

# %rm "cached_data/34_optuna.sqlite3"  # FORCING RECOMPUTE
# Out:
# rm: cached_data/34_optuna.sqlite3: No such file or directory

# %%
import warnings
from optuna.exceptions import ExperimentalWarning
warnings.filterwarnings("ignore", category=ExperimentalWarning,
    # module=r"optuna\._experimental"
)

# %%
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
import retinoto_py as fovea
dataset = 'focus'
batch_size = 64
args = fovea.Params()
opts_dict = dict(do_fovea=True, subset_factor=25, num_epochs=1, verbose=False)
args = dataclasses.replace(args, **opts_dict)
args
# Out:
# Welcome on macOS-26.1-arm64-arm-64bit-Mach-O	- Timestamp (UTC)  2025-12-05_08-08-01	 user laurentperrinet	Running on MPS device (Apple Silicon/MacOS)	 - macos_version = 26.1	 with device mps, pytorch==2.9.1
# Random seed 2018 has been set.
# Params(image_size=224, do_mask=False, do_fovea=True, rs_min=0.0, rs_max=-6.0, padding_mode='zeros', seed=2018, batch_size=80, num_workers=1, in_memory=False, model_name='convnext_base', num_epochs=1, subset_factor=25, lr=1e-06, delta1=0.1, delta2=0.007, weight_decay=0.03, label_smoothing=0.2, shuffle=True, verbose=False)

# %%
model_filename = None # do not use resumed net
model_filename = args.data_cache / f'32_fovea_model_name={args.model_name}_dataset={dataset}.pth'

# %%
TRAIN_DATA_DIR = args.DATAROOT / f'Imagenet_{dataset}' / 'train'
train_dataset = fovea.get_dataset(args, TRAIN_DATA_DIR)
train_loader = fovea.get_loader(args, train_dataset)
VAL_DATA_DIR = args.DATAROOT / f'Imagenet_{dataset}' / 'val'
val_dataset = fovea.get_dataset(args, VAL_DATA_DIR)
val_loader = fovea.get_loader(args, val_dataset)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 TRAIN_DATA_DIR = args.DATAROOT / f'Imagenet_{dataset}' / 'train'
# ----> 2 train_dataset = fovea.get_dataset(args, TRAIN_DATA_DIR)
#       3 train_loader = fovea.get_loader(args, train_dataset)
#       4 VAL_DATA_DIR = args.DATAROOT / f'Imagenet_{dataset}' / 'val'
#
# File ~/app54-nextcloud/science/retinoto_py/src/retinoto_py/torch_utils.py:277, in get_dataset(args, DATA_DIR, angle_min, angle_max, in_memory, n_stop)
#     275     dataset = InMemoryImageDataset(root=DATA_DIR, transform=preprocess, n_stop=n_stop, is_valid_file=is_valid_file, seed=args.seed)
#     276 else:
# --> 277     dataset = datasets.ImageFolder(root=DATA_DIR, transform=preprocess, is_valid_file=is_valid_file)
#     278     if n_stop>0: raise('not implemented')
#     279 # # The dataset provides a mapping from class index to class name (folder name)
#     280 # class_to_idx = dataset.class_to_idx
#     281 # # We often want the inverse mapping for printing results
#     282 # idx_to_class = {v: k for k, v in class_to_idx.items()}
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torchvision/datasets/folder.py:328, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     319 def __init__(
#     320     self,
#     321     root: Union[str, Path],
#    (...)    326     allow_empty: bool = False,
#     327 ):
# --> 328     super().__init__(
#     329         root,
#     330         loader,
#     331         IMG_EXTENSIONS if is_valid_file is None else None,
#     332         transform=transform,
#     333         target_transform=target_transform,
#     334         is_valid_file=is_valid_file,
#     335         allow_empty=allow_empty,
#     336     )
#     337     self.imgs = self.samples
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torchvision/datasets/folder.py:149, in DatasetFolder.__init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     138 def __init__(
#     139     self,
#     140     root: Union[str, Path],
#    (...)    146     allow_empty: bool = False,
#     147 ) -> None:
#     148     super().__init__(root, transform=transform, target_transform=target_transform)
# --> 149     classes, class_to_idx = self.find_classes(self.root)
#     150     samples = self.make_dataset(
#     151         self.root,
#     152         class_to_idx=class_to_idx,
#    (...)    155         allow_empty=allow_empty,
#     156     )
#     158     self.loader = loader
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torchvision/datasets/folder.py:234, in DatasetFolder.find_classes(self, directory)
#     207 def find_classes(self, directory: Union[str, Path]) -> tuple[list[str], dict[str, int]]:
#     208     """Find the class folders in a dataset structured as follows::
#     209
#     210         directory/
#    (...)    232         (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     233     """
# --> 234     return find_classes(directory)
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torchvision/datasets/folder.py:41, in find_classes(directory)
#      36 def find_classes(directory: Union[str, Path]) -> tuple[list[str], dict[str, int]]:
#      37     """Finds the class folders in a dataset.
#      38
#      39     See :class:`DatasetFolder` for details.
#      40     """
# ---> 41     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      42     if not classes:
#      43         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/laurentperrinet/data/Imagenet/Imagenet_focus/train'

# %%
def objective(trial):
    args = fovea.Params()
    args = dataclasses.replace(args, **opts_dict)
    model = fovea.load_model(args, model_filename=model_filename)

    # # args.batch_size = trial.suggest_int('batch_size', 16, 512, log=True, step=1)
    # # args.rs_min = trial.suggest_float('rs_min', -1, 1.)
    # # args.rs_max = trial.suggest_float('rs_max', -7, -4)
    scale = 10
    # if args.delta2>0: args.delta2 = trial.suggest_float('delta2', 0.001, 0.9, log=True)
    args.lr = trial.suggest_float('lr', args.lr / scale, args.lr * scale, log=True)

    args.delta1 = trial.suggest_float('delta1', args.delta1 / scale, min((args.delta1 * scale, 1)), log=True)
    # weight_decay = 0.005 if opt.weight_decay==0 else opt.weight_decay
    # args.weight_decay = trial.suggest_float('weight_decay', args.weight_decay / scale, min((args.weight_decay * scale, 1)), log=True)
    args.weight_decay = trial.suggest_float('weight_decay', args.weight_decay / scale, args.weight_decay * scale, log=True)

    scale = 100 
    # label_smoothing = 0.005 if opt.label_smoothing==0 else opt.label_smoothing
    # args.label_smoothing = trial.suggest_float('label_smoothing', label_smoothing / scale, label_smoothing * scale, log=True)

    # args.im_mean = trial.suggest_float('im_mean', opt.im_mean / scale, opt.im_mean * scale, log=True)
    # args.im_std = trial.suggest_float('im_std', opt.im_std / scale, opt.im_std * scale, log=True)


    # get the architecture of the network, train and get accuracy on the validation set
    _, df_train = fovea.train_model(args, model=model, train_loader=train_loader, val_loader=val_loader)
    accuracy = df_train['acc_val'].mean()
    
    return accuracy
    
# 3. Create a study object and optimize the objective function.
study = optuna.create_study(storage=f"sqlite:///cached_data/34_optuna.sqlite3", 
                            sampler=optuna.samplers.TPESampler(multivariate=False, warn_independent_sampling=False),
                            direction='maximize', load_if_exists=True, study_name=f"34_optuna")
print(f'Starting optimization with params: {args} on {max(150-len(study.trials), 0)} trials - {len(study.trials)} ')
study.optimize(objective, n_trials=max((150-len(study.trials), 0)), n_jobs=1, show_progress_bar=True)

print(50*'-.')
print("Best params: ", study.best_params)
print("Best value: ", study.best_value)
print("Best Trial: ", study.best_trial)
# print("Trials: ", study.trials)
# Out:
# Starting optimization with params: Params(image_size=224, do_mask=False, do_fovea=True, rs_min=0.0, rs_max=-6.0, padding_mode='zeros', seed=2018, batch_size=80, num_workers=1, in_memory=False, model_name='convnext_base', num_epochs=1, subset_factor=25, lr=1e-06, delta1=0.1, delta2=0.007, weight_decay=0.03, label_smoothing=0.2, shuffle=True, verbose=False) on 150 trials - 0
#   0%|          | 0/150 [00:00<?, ?it/s]
# [W 2025-12-05 09:08:03,125] Trial 0 failed with parameters: {} because of the following error: FileNotFoundError(2, 'No such file or directory').
# Traceback (most recent call last):
#   File "/Users/laurentperrinet/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/optuna/study/_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/3s/q2x8bxzj43g4rdvb2wjt67640000gq/T/ipykernel_30149/276707811.py", line 4, in objective
#     model = fovea.load_model(args, model_filename=model_filename)
#   File "/Users/laurentperrinet/app54-nextcloud/science/retinoto_py/src/retinoto_py/torch_utils.py", line 358, in load_model
#     model = apply_weights(model, model_filename, args.device, verbose=args.verbose)
#   File "/Users/laurentperrinet/app54-nextcloud/science/retinoto_py/src/retinoto_py/torch_utils.py", line 373, in apply_weights
#     model.load_state_dict(torch.load(model_filename, map_location=torch.device(device)))
#                           ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurentperrinet/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torch/serialization.py", line 1484, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ~~~~~~~~~~~~~~~^^^^^^^^^
#   File "/Users/laurentperrinet/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torch/serialization.py", line 759, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/laurentperrinet/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torch/serialization.py", line 740, in __init__
#     super().__init__(open(name, mode))
#                      ~~~~^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'cached_data/32_fovea_model_name=convnext_base_dataset=focus.pth'
# [W 2025-12-05 09:08:03,127] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 37
#      33 study = optuna.create_study(storage=f"sqlite:///cached_data/34_optuna.sqlite3",
#      34                             sampler=optuna.samplers.TPESampler(multivariate=False, warn_independent_sampling=False),
#      35                             direction='maximize', load_if_exists=True, study_name=f"34_optuna")
#      36 print(f'Starting optimization with params: {args} on {max(150-len(study.trials), 0)} trials - {len(study.trials)} ')
# ---> 37 study.optimize(objective, n_trials=max((150-len(study.trials), 0)), n_jobs=1, show_progress_bar=True)
#      39 print(50*'-.')
#      40 print("Best params: ", study.best_params)
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/optuna/study/_optimize.py:67, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      65 try:
#      66     if n_jobs == 1:
# ---> 67         _optimize_sequential(
#      68             study,
#      69             func,
#      70             n_trials,
#      71             timeout,
#      72             catch,
#      73             callbacks,
#      74             gc_after_trial,
#      75             reseed_sampler_rng=False,
#      76             time_start=None,
#      77             progress_bar=progress_bar,
#      78         )
#      79     else:
#      80         if n_jobs == -1:
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/optuna/study/_optimize.py:164, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161         break
#     163 try:
# --> 164     frozen_trial_id = _run_trial(study, func, catch)
#     165 finally:
#     166     # The following line mitigates memory problems that can be occurred in some
#     167     # environments (e.g., services that use computing containers such as GitHub Actions).
#     168     # Please refer to the following PR for further details:
#     169     # https://github.com/optuna/optuna/pull/325.
#     170     if gc_after_trial:
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/optuna/study/_optimize.py:262, in _run_trial(study, func, catch)
#     255         assert False, "Should not reach."
#     257 if (
#     258     updated_state == TrialState.FAIL
#     259     and func_err is not None
#     260     and not isinstance(func_err, catch)
#     261 ):
# --> 262     raise func_err
#     263 return trial._trial_id
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/optuna/study/_optimize.py:205, in _run_trial(study, func, catch)
#     203 with get_heartbeat_thread(trial._trial_id, study._storage):
#     204     try:
# --> 205         value_or_values = func(trial)
#     206     except exceptions.TrialPruned as e:
#     207         # TODO(mamu): Handle multi-objective cases.
#     208         state = TrialState.PRUNED
#
# Cell In[8], line 4, in objective(trial)
#       2 args = fovea.Params()
#       3 args = dataclasses.replace(args, **opts_dict)
# ----> 4 model = fovea.load_model(args, model_filename=model_filename)
#       6 # # args.batch_size = trial.suggest_int('batch_size', 16, 512, log=True, step=1)
#       7 # # args.rs_min = trial.suggest_float('rs_min', -1, 1.)
#       8 # # args.rs_max = trial.suggest_float('rs_max', -7, -4)
#       9 scale = 10
#
# File ~/app54-nextcloud/science/retinoto_py/src/retinoto_py/torch_utils.py:358, in load_model(args, model_filename)
#     355 model = model.to(args.device)
#     357 if not model_filename is None:
# --> 358     model = apply_weights(model, model_filename, args.device, verbose=args.verbose)
#     360 return model
#
# File ~/app54-nextcloud/science/retinoto_py/src/retinoto_py/torch_utils.py:373, in apply_weights(model, model_filename, device, verbose)
#     363 """
#     364 Apply the weights to the model.
#     365 Args:
#    (...)    370     model: torch model, the model with the weights applied
#     371     """
#     372 if verbose: print(f'loading .... {model_filename}')
# --> 373 model.load_state_dict(torch.load(model_filename, map_location=torch.device(device)))
#     374 return model
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torch/serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
#    1485     if _is_zipfile(opened_file):
#    1486         # The zipfile reader is going to advance the current file position.
#    1487         # If we want to actually tail call to torch.jit.load, we need to
#    1488         # reset back to the original position.
#    1489         orig_position = opened_file.tell()
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torch/serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/torch/serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cached_data/32_fovea_model_name=convnext_base_dataset=focus.pth'

# %%
import optuna.visualization.matplotlib as vis

# %%
vis.plot_param_importances(study)
# Out:
# [W 2025-12-05 09:08:04,100] Study instance does not contain completed trials.
# /Users/laurentperrinet/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/optuna/visualization/matplotlib/_param_importances.py:111: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc="best")
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %%
# df = study.trials_dataframe()   
params = sorted({k for t in study.trials for k in t.params})
params
# Out:
# []

# %%
fig, axes = fovea.plt.subplots(len(params), 1, figsize=(15, 8*len(params)), sharey=True)

for ax, pname in zip(axes, params):
    xs = [t.params[pname] for t in study.trials if pname in t.params]
    ys = [t.value for t in study.trials if pname in t.params]
    ax.scatter(xs, ys, s=20, alpha=0.6)
    ax.set_xlabel(pname)
    ax.set_ylabel("Objective")

fovea.plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 fig, axes = fovea.plt.subplots(len(params), 1, figsize=(15, 8*len(params)), sharey=True)
#       3 for ax, pname in zip(axes, params):
#       4     xs = [t.params[pname] for t in study.trials if pname in t.params]
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/matplotlib/pyplot.py:1777, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1632 """
#    1633 Create a figure and a set of subplots.
#    1634
#    (...)   1774
#    1775 """
#    1776 fig = figure(**fig_kw)
# -> 1777 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1778                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1779                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1780                    width_ratios=width_ratios)
#    1781 return fig, axs
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/matplotlib/figure.py:918, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     914         raise ValueError("'width_ratios' must not be defined both as "
#     915                          "parameter and as key in 'gridspec_kw'")
#     916     gridspec_kw['width_ratios'] = width_ratios
# --> 918 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     919 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     920                   subplot_kw=subplot_kw)
#     921 return axs
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/matplotlib/figure.py:1600, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1557 """
#    1558 Low-level API for creating a `.GridSpec` that has this figure as a parent.
#    1559
#    (...)   1596
#    1597 """
#    1599 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1600 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1601 return gs
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/matplotlib/gridspec.py:363, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     360 self.hspace = hspace
#     361 self.figure = figure
# --> 363 super().__init__(nrows, ncols,
#     364                  width_ratios=width_ratios,
#     365                  height_ratios=height_ratios)
#
# File ~/app54-nextcloud/science/retinoto_py/.venv/lib/python3.13/site-packages/matplotlib/gridspec.py:48, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      33 """
#      34 Parameters
#      35 ----------
#    (...)     45     If not given, all rows will have the same height.
#      46 """
#      47 if not isinstance(nrows, Integral) or nrows <= 0:
# ---> 48     raise ValueError(
#      49         f"Number of rows must be a positive integer, not {nrows!r}")
#      50 if not isinstance(ncols, Integral) or ncols <= 0:
#      51     raise ValueError(
#      52         f"Number of columns must be a positive integer, not {ncols!r}")
#
# ValueError: Number of rows must be a positive integer, not 0
