# %% [markdown]
# - author: John Doe
# - date: 2018-05-11
# - category: pyhton
# - tags: pip

# %% [markdown]
# # Installation
#
# 1. create a venv
#
# ````
# python3 -m venv .venv
#
# ````
#
# 2. install libraries :

# %%
# %pip install -q -U -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -e .
# Out:
# Obtaining file:///Users/laurent/science/retinoto_py
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: typer in ./.venv/lib/python3.13/site-packages (from retinoto_py==20251122) (0.20.0)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.13/site-packages (from typer->retinoto_py==20251122) (8.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.13/site-packages (from typer->retinoto_py==20251122) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.13/site-packages (from typer->retinoto_py==20251122) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.13/site-packages (from typer->retinoto_py==20251122) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer->retinoto_py==20251122) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer->retinoto_py==20251122) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->retinoto_py==20251122) (0.1.2)
# Building wheels for collected packages: retinoto_py
#   Building editable for retinoto_py (pyproject.toml) ... done
#   Created wheel for retinoto_py: filename=retinoto_py-20251122-0.editable-py3-none-any.whl size=2964 sha256=5a6f5c9f94c9a07c7736f5e32e015df7d22f427224b33d28b97f1e74e9ba25a1
#   Stored in directory: /private/var/folders/qt/n82pbkv93fjb7bpt0pj1992w0000gn/T/pip-ephem-wheel-cache-goynpumz/wheels/ec/39/bf/8f679799ec613017063ea87d5454c794121f6ed67a3790f561
# Successfully built retinoto_py
# Installing collected packages: retinoto_py
#   Attempting uninstall: retinoto_py
#     Found existing installation: retinoto_py 20251122
#     Uninstalling retinoto_py-20251122:
#       Successfully uninstalled retinoto_py-20251122
# Successfully installed retinoto_py-20251122
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 3. activate it:
#
# ````
# source .venv/bin/activate
#
# ````

# %%
from retinoto_py import Params
args = Params()
args
# Out:
# Welcome on macOS-26.1-arm64-arm-64bit-Mach-O	 user laurent	Running on MPS device (Apple Silicon/MacOS)	 - macos_version = 26.1	 with device mps, pytorch==2.9.1
# Random seed 1998 has been set.
# Params(image_size=224, do_mask=True, seed=1998, batch_size=64, num_workers=4, model_name='resnet50', do_scratch=False, num_epochs=50, n_train_stop=19200, n_val_stop=6400, lr=0.0001, delta1=0.05, delta2=0.001, weight_decay=0.0, shuffle=True, verbose=True)

# %% [markdown]
# 4. test the imports:

# %% [markdown]
# 5. ImageNet  Data set

# %% [markdown]
# Now import images from  the [ImageNet website](https://image-net.org/challenges/LSVRC/2010/2010-downloads.php) following the instructions for [`torchvision.datasets.ImageNet`](https://pytorch.org/vision/stable/generated/torchvision.datasets.ImageNet.html).
#
# Then gather the ``ILSVRC2012_img_train.tar`` and ``ILSVRC2012_img_val.tar`` files into the folder defined as the `DATAROOT` parameter in the `retinotopy.py` file and extract the archive (takes time!).

# %%
# uncomment to do that
# !cd data; sh extract_ILSVRC.sh  # extract ILSVRC2012 dataset

# %% [markdown]
# Note that we will use the localisation data from https://www.kaggle.com/c/imagenet-object-localization-challenge/data

# %% [markdown]
# ## Appendix: version of the libraries that were used

# %%
# %load_ext watermark
# %watermark -i -h -m -v -p numpy,torch,matplotlib  -r -g -b
# Out:
# Python implementation: CPython
# Python version       : 3.13.9
# IPython version      : 9.7.0
#
# numpy     : 2.2.6
# torch     : 2.9.1
# matplotlib: 3.10.7
#
# Compiler    : Clang 17.0.0 (clang-1700.3.19.1)
# OS          : Darwin
# Release     : 25.1.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 32
# Architecture: 64bit
#
# Hostname: gaia
#
# Git hash: 0a69d3a71b7bc1b0f8863be44a1418a0930eb92e
#
# Git repo: https://github.com/laurentperrinet/retinoto_py.git
#
# Git branch: main

# %% [markdown]
# Voilà !
