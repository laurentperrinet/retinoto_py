# %% [markdown]
# - author: John Doe
# - date: 2018-05-11
# - category: pyhton
# - tags: pip

# %%
# %%bash
# find . -name "*.ipynb" -not -name "05*" -not -name "99*" -not -name "*with*"

# %%
# %%bash
# find . -name "*.ipynb" -not -name "05*" -not -name "99*" -not -name "*with*" -exec jupyter nbconvert --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace {} \;

# %%
# !find -s . -name "*benchmarking*.ipynb"

# %%
# %%bash
# jupyter nbconvert --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace 20_transfer-learning.ipynb
# jupyter nbconvert --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace 32_transfer-learning-convnext-fovea.ipynb
# Out:
# [NbConvertApp] Converting notebook 20_transfer-learning.ipynb to notebook
# [NbConvertApp] ERROR | Notebook JSON is invalid: 'execution_count' is a required property
#
# Failed validating 'required' in code_cell:
#
# On instance['cells'][1]:
# {'cell_type': 'code',
#  'id': 'efdb6e14-6ce3-481d-9afc-61b1cfee1168',
#  'metadata': {'execution': {'iopub.execute_input': '2025-12-05T08:07:43.492392Z',
#                             'iopub.status.busy': '2025-12-05T08:07:43.491472Z',
#                             'iopub.status.idle': '2025-12-05T08:07:45.505629Z',
#                             'shell.execute_reply': '2025-12-05T08:07:45.505181Z'},
#               'tags': []},
#  'outputs': ['...0 outputs...'],
#  'source': 'import retinoto_py as fovea\n'
#            'args = fovea.Params(do_mask=True, nu...'}
# [NbConvertApp] ERROR | Notebook is invalid after preprocessor <nbconvert.preprocessors.tagremove.TagRemovePreprocessor object at 0x10b0fb930>
# Traceback (most recent call last):
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/bin/jupyter-nbconvert", line 7, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/jupyter_core/application.py", line 284, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     ~~~~~~~~~^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/nbconvertapp.py", line 420, in start
#     self.convert_notebooks()
#     ~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/nbconvertapp.py", line 563, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#                         ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         notebook_filename, resources, input_buffer=input_buffer
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/nbconvertapp.py", line 487, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#                         ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         notebook_filename, resources=resources
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/exporters/exporter.py", line 201, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#            ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/exporters/exporter.py", line 220, in from_file
#     return self.from_notebook_node(
#            ~~~~~~~~~~~~~~~~~~~~~~~^
#         nbformat.read(file_stream, as_version=4), resources=resources, **kw
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/exporters/notebook.py", line 36, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/exporters/exporter.py", line 154, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#                          ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/exporters/exporter.py", line 355, in _preprocess
#     self._validate_preprocessor(nbc, preprocessor)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbconvert/exporters/exporter.py", line 322, in _validate_preprocessor
#     nbformat.validate(nbc, relax_add_props=True)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/laurent/app54_nextcloud/science/retinoto_py/.venv/lib/python3.14/site-packages/nbformat/validator.py", line 509, in validate
#     raise error
# nbformat.validator.NotebookValidationError: 'execution_count' is a required property
#
# Failed validating 'required' in code_cell:
#
# On instance['cells'][1]:
# {'cell_type': 'code',
#  'id': 'efdb6e14-6ce3-481d-9afc-61b1cfee1168',
#  'metadata': {'execution': {'iopub.execute_input': '2025-12-05T08:07:43.492392Z',
#                             'iopub.status.busy': '2025-12-05T08:07:43.491472Z',
#                             'iopub.status.idle': '2025-12-05T08:07:45.505629Z',
#                             'shell.execute_reply': '2025-12-05T08:07:45.505181Z'},
#               'tags': []},
#  'outputs': ['...0 outputs...'],
#  'source': 'import retinoto_py as fovea\n'
#            'args = fovea.Params(do_mask=True, nu...'}
# [NbConvertApp] Converting notebook 32_transfer-learning-convnext-fovea.ipynb to notebook
# [NbConvertApp] Writing 411518 bytes to 32_transfer-learning-convnext-fovea.ipynb

# %%
# !find -s . -name "*benchmarking*.ipynb" -exec jupyter nbconvert --ExecutePreprocessor.kernel_name=python3 --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace {} \;

# %%
# !jupyter nbconvert --ExecutePreprocessor.kernel_name=python3 --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace

# %%
# !find -s . -name "*benchmarking*.ipynb" -exec jupyter nbconvert --ExecutePreprocessor.kernel_name=python3 --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace {} \;

# %% [markdown]
# # checking vanilla inference

# %%
# %run -i "05_imagenet-bbox-dataset.ipynb"

# %%
# %run -i "11_faster_inference.ipynb"

# %%
# %run -i "12_benchmarking_inference_loader.ipynb"

# %%
# %whos

# %%
# %run -i "13_benchmarking_inference_models.ipynb"

# %%
# %run -i "14_benchmarking_inference_convnext_models.ipynb"

# %%
# %run -i "16_rotation_attack_sample.ipynb"

# %%
# %run -i "17_rotation_attack.ipynb"

# %%
# %run -i "20_transfer-learning.ipynb"

# %%
# %run -i "23_benchmarking_inference_retrained-models.ipynb"

# %%
# %run -i "27_rotation_attack-after-retraining.ipynb"

# %% [markdown]
# # introducing a fovea

# %%
# %run -i "30_retinotopic-mapping.ipynb"

# %%
# %run -i "31_transfer-learning-fovea.ipynb"

# %%
# %run -i "32_transfer-learning-convnext-fovea.ipynb"

# %%
# %run -i "33_benchmarking_inference_models.ipynb"

# %%
# %run -i "34_optimize-bbox.ipynb"

# %%
# %run -i "37_rotation_attack-after-retraining.ipynb"

# %% [markdown]
# # emerging localization properties

# %%
# %run -i "40_compute_likelihood_map.ipynb"

# %%
# %ls *.ipynb

# %%
# %run -i "41_multiple_likelihood_map.ipynb"

# %%
# %run -i "42_imagenet-focus-dataset.ipynb"

# %%
# %run -i "43_transfer_learning_focus.ipynb"

# %% [markdown]
# # learning where things are

# %% [markdown]
# Note that we will use the localisation data from https://www.kaggle.com/c/imagenet-object-localization-challenge/data

# %% [markdown]
# ## Appendix: version of the libraries that were used

# %%
# %load_ext watermark
# %watermark -i -h -m -v -p numpy,torch,matplotlib  -r -g -b

# %% [markdown]
# Voilà !
