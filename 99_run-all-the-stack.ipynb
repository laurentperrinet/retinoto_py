# %% [markdown]
# - author: John Doe
# - date: 2018-05-11
# - category: pyhton
# - tags: pip

# %%
# !find -s . -name "*.ipynb" -exec jupyter nbconvert --ExecutePreprocessor.kernel_name=python3 --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace {} \;

# %%
# !find -s . -name "*benchmarking*.ipynb"
# Out:
# ./12_benchmarking_inference_loader.ipynb
# ./13_benchmarking_inference_models.ipynb
# ./14_benchmarking_inference_convnext_models.ipynb
# ./23_benchmarking_inference_retrained-models.ipynb
# ./33_benchmarking_inference_models.ipynb

# %%
# !find -s . -name "*benchmarking*.ipynb" -exec jupyter nbconvert --ExecutePreprocessor.kernel_name=python3 --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace {} \;
# Out:
# [NbConvertApp] Converting notebook ./12_benchmarking_inference_loader.ipynb to notebook

# %%
# !jupyter nbconvert --ExecutePreprocessor.kernel_name=python3 --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace
# Out:
# [NbConvertApp] Converting notebook ./12_benchmarking_inference_loader.ipynb to notebook

# %%
# !find -s . -name "*benchmarking*.ipynb" -exec jupyter nbconvert --ExecutePreprocessor.kernel_name=python3 --ExecutePreprocessor.timeout=0 --allow-errors --execute  --to notebook --inplace {} \;
# Out:
# [NbConvertApp] Converting notebook ./12_benchmarking_inference_loader.ipynb to notebook

# %% [markdown]
# # checking vanilla inference

# %%
# %run "05_imagenet-bbox-dataset.ipynb"

# %%
# %run "11_faster_inference.ipynb"

# %%
# %run "12_benchmarking_inference_loader.ipynb"

# %%
# %whos

# %%
# %run "13_benchmarking_inference_models.ipynb"
# Out:
# Welcome on macOS-26.1-arm64-arm-64bit-Mach-O	- Timestamp (UTC)  2025-12-04_10-03-46	 user laurentperrinet	Running on MPS device (Apple Silicon/MacOS)	 - macos_version = 26.1	 with device mps, pytorch==2.9.1
# Random seed 2018 has been set.

# %%
# %run "14_benchmarking_inference_convnext_models.ipynb"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /var/folders/3s/q2x8bxzj43g4rdvb2wjt67640000gq/T/ipykernel_4883/1066353682.py:1
# ----> 1 combined_all_datasets = pd.concat([results13, results14], ignore_index=True)
#       2 combined_model_names = fovea.all_model_names.extend(fovea.all_cn_model_names)
#       3 combined_all_datasets = fovea.all_datasets.extend(fovea.all_datasets)
#
# NameError: name 'pd' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', '"14_benchmarking_inference_convnext_models.ipynb"')
#
# ...

# %%
# %run "16_rotation_attack_sample.ipynb"

# %%
# %run "17_rotation_attack.ipynb"

# %%
# %run "20_transfer-learning.ipynb"

# %%
# %run "23_benchmarking_inference_retrained-models.ipynb"

# %%
# %run "27_rotation_attack-after-retraining.ipynb"

# %% [markdown]
# # introducing a fovea

# %%
# %run "30_retinotopic-mapping.ipynb"

# %%
# %run "31_transfer-learning-fovea.ipynb"

# %%
# %run "32_transfer-learning-convnext-fovea.ipynb"

# %%
# %run "33_benchmarking_inference_models.ipynb"

# %%
# %run "34_optimize-bbox.ipynb"

# %%
# %run "37_rotation_attack-after-retraining.ipynb"

# %% [markdown]
# # emerging localization properties

# %%
# %run "40_compute_likelihood_map.ipynb"

# %%
# %ls *.ipynb
# Out:
# 00_installation.ipynb
# 05_imagenet-bbox-dataset.ipynb
# 08_dataloaders.ipynb
# 10_inference.ipynb
# 11_faster_inference.ipynb
# 12_benchmarking_inference_loader.ipynb
# 13_benchmarking_inference_models.ipynb
# 14_benchmarking_inference_convnext_models.ipynb
# 16_rotation_attack_sample.ipynb
# 17_rotation_attack.ipynb
# 20_transfer-learning.ipynb
# 23_benchmarking_inference_retrained-models.ipynb
# 30_retinotopic-mapping.ipynb
# 32_transfer-learning-resnet101-fovea.ipynb
# 33_transfer-learning-convnext-fovea.ipynb
# 34_optimize-bbox.ipynb
# 37_rotation_attack-after-retraining.ipynb
# 40_compute_likelihood_map.ipynb
# 41_multiple_likelihood_map.ipynb
# 42_imagenet-focus-dataset.ipynb
# 43_transfer_learning_focus.ipynb
# 44_optimise_focus.ipynb
# 49_pareidolia_map.ipynb
# 99_run-all-the-stack.ipynb

# %%
# %run "41_multiple_likelihood_map.ipynb"

# %%
# %run "42_imagenet-focus-dataset.ipynb"

# %%
# %run "43_transfer_learning_focus.ipynb"

# %% [markdown]
# # learning where things are

# %% [markdown]
# Note that we will use the localisation data from https://www.kaggle.com/c/imagenet-object-localization-challenge/data

# %% [markdown]
# ## Appendix: version of the libraries that were used

# %%
# %load_ext watermark
# %watermark -i -h -m -v -p numpy,torch,matplotlib  -r -g -b
# Out:
# Python implementation: CPython
# Python version       : 3.13.9
# IPython version      : 9.7.0
#
# numpy     : 2.2.6
# torch     : 2.9.1
# matplotlib: 3.10.7
#
# Compiler    : Clang 17.0.0 (clang-1700.3.19.1)
# OS          : Darwin
# Release     : 25.1.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 10
# Architecture: 64bit
#
# Hostname: obiwan.local
#
# Git hash: 9221793b06b0d422ef118500a7740629aa3f9288
#
# Git repo: https://github.com/laurentperrinet/retinoto_py.git
#
# Git branch: main

# %% [markdown]
# Voilà !
