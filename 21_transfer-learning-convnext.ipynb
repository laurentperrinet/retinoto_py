# %% [markdown]
# In this notebook, we perform transfer learning on a ConvNeXt model (specifically convnext_base) using the ImageNet dataset with different masking strategies (with or without) and datasets (full image vs. bounding box). We evaluate the model's performance, compare results across different datasets, and visualize the learning evolution (training and validation accuracy) over time to assess the impact of masking on learning efficiency and robustness.

# %%
import retinoto_py as fovea
model_name = 'convnext_base'
args = fovea.Params(do_fovea=False, do_mask=True, model_name=model_name, num_epochs=40)
args
# Out:
# Params(batch_size=128, num_workers=0, prefetch_factor=0, image_size=224, grid_size_ecc=161, grid_size_ang=309, do_mask=True, do_fovea=False, use_hexagonal_grid=True, rs_min=-3.5, rs_max=0.7, angle_start=-5.235987755982989, angle_margin=0.010166966516471823, mode='bilinear', padding_mode='zeros', model_name='convnext_base', num_epochs=40, subset_factor=1, optimizer_name='adamw', loss_name='CrossEntropyLoss', base_lr=1e-06, final_lr=1e-09, num_warmup_epochs=20, delta1=0.3, delta2=0.002, weight_decay=0.0001, label_smoothing=0.0005, do_full_training=True, do_augment=True, augment_proba=0.85, stochastic_depth_prob=0.6, seed=1998, shuffle=True, verbose=False)

# %% [markdown]
# # transfer learning of each network on the  masked dataset

# %%
# %ls -ltr cached_data/21*
# Out:
# -rw-r--r--@ 1 laurent  staff  1063545885  1 juin  07:59 cached_data/21_model_name=convnext_base_dataset=full.pth
# -rw-r--r--@ 1 laurent  staff        7697  1 juin  07:59 cached_data/21_model_name=convnext_base_dataset=full.json
# -rw-r-----@ 1 laurent  staff  1063545885  5 juin  02:56 cached_data/21_model_name=convnext_base_dataset=bbox.pth
# -rw-r-----@ 1 laurent  staff        7656  5 juin  02:56 cached_data/21_model_name=convnext_base_dataset=bbox.json

# %%
# %rm "cached_data/21_model_name=convnext_base_dataset=bbox.lock"   # FORCING RECOMPUTE
# %rm "cached_data/21_model_name*.lock"   # FORCING RECOMPUTE
# %rm "cached_data/21_model_name=convnext_base_dataset=bbox.lock"   # FORCING RECOMPUTE
# %rm cached_data/20*
# Out:
# rm: cached_data/21_model_name*.lock: No such file or directory

# %%
model_name = args.model_name
for dataset in fovea.params.all_datasets:
    name = f'21_model_name={model_name}_dataset={dataset}'
    model_filename, json_filename = fovea.do_learning(args, dataset, name)
# Out:
# Load JSON from pre-trained resnet cached_data/21_model_name=convnext_base_dataset=full.json
# cached_data/21_model_name=convnext_base_dataset=full.pth: latest accuracy = 0.832
# Training model convnext_base, file= cached_data/21_model_name=convnext_base_dataset=full.pth - image_size=224
# Resuming learning from epoch 18 with 8968064 images already seen...
# Epochs:   0%|          | 0/22 [00:00<?, ?it/s]
# Epoch=19/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=20/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=21/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=22/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=23/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=24/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=25/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=26/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=27/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=28/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=29/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=30/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=31/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=32/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=33/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=34/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=35/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=36/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=37/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=38/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=39/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Epoch=40/40:   0%|          | 0/10009 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/390 [00:00<?, ?it/s]
# Training of ConvNeXt(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#       (1): LayerNorm2d((128,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#           (1): Permute()
#           (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=128, out_features=512, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=512, out_features=128, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#           (1): Permute()
#           (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=128, out_features=512, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=512, out_features=128, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.017142857142857144, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#           (1): Permute()
#           (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=128, out_features=512, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=512, out_features=128, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.03428571428571429, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): LayerNorm2d((128,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(128, 256, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (3): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#           (1): Permute()
#           (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=256, out_features=1024, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1024, out_features=256, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.05142857142857142, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#           (1): Permute()
#           (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=256, out_features=1024, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1024, out_features=256, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.06857142857142857, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#           (1): Permute()
#           (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=256, out_features=1024, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1024, out_features=256, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.08571428571428572, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): LayerNorm2d((256,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(256, 512, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (5): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.10285714285714284, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.12000000000000001, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.13714285714285715, mode=row)
#       )
#       (3): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.15428571428571428, mode=row)
#       )
#       (4): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.17142857142857143, mode=row)
#       )
#       (5): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.18857142857142856, mode=row)
#       )
#       (6): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.20571428571428568, mode=row)
#       )
#       (7): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.22285714285714286, mode=row)
#       )
#       (8): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.24000000000000002, mode=row)
#       )
#       (9): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2571428571428571, mode=row)
#       )
#       (10): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2742857142857143, mode=row)
#       )
#       (11): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2914285714285714, mode=row)
#       )
#       (12): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.30857142857142855, mode=row)
#       )
#       (13): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.32571428571428573, mode=row)
#       )
#       (14): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.34285714285714286, mode=row)
#       )
#       (15): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.36, mode=row)
#       )
#       (16): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.3771428571428571, mode=row)
#       )
#       (17): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.39428571428571424, mode=row)
#       )
#       (18): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.41142857142857137, mode=row)
#       )
#       (19): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.42857142857142855, mode=row)
#       )
#       (20): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.44571428571428573, mode=row)
#       )
#       (21): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.46285714285714286, mode=row)
#       )
#       (22): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.48000000000000004, mode=row)
#       )
#       (23): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4971428571428571, mode=row)
#       )
#       (24): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5142857142857142, mode=row)
#       )
#       (25): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5314285714285714, mode=row)
#       )
#       (26): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5485714285714286, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): LayerNorm2d((512,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(512, 1024, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (7): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#           (1): Permute()
#           (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1024, out_features=4096, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=4096, out_features=1024, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5657142857142857, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#           (1): Permute()
#           (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1024, out_features=4096, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=4096, out_features=1024, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5828571428571429, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#           (1): Permute()
#           (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1024, out_features=4096, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=4096, out_features=1024, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.6, mode=row)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): LayerNorm2d((1024,), eps=1e-06, elementwise_affine=True)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=1024, out_features=1000, bias=True)
#   )
# ) completed in 8353m 21s
# Load JSON from pre-trained resnet cached_data/21_model_name=convnext_base_dataset=bbox.json
# cached_data/21_model_name=convnext_base_dataset=bbox.pth: latest accuracy = 0.819
# Training model convnext_base, file= cached_data/21_model_name=convnext_base_dataset=bbox.pth - image_size=224
# Resuming learning from epoch 10 with 6152320 images already seen...
# Epochs:   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch=11/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=12/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=13/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=14/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=15/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=16/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=17/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=18/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=19/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=20/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=21/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=22/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=23/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=24/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=25/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=26/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=27/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=28/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=29/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=30/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=31/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=32/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=33/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=34/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=35/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=36/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=37/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=38/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=39/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Epoch=40/40:   0%|          | 0/4806 [00:00<?, ?it/s]
# Evaluating convnext_base:   0%|          | 0/628 [00:00<?, ?it/s]
# Training of ConvNeXt(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#       (1): LayerNorm2d((128,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#           (1): Permute()
#           (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=128, out_features=512, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=512, out_features=128, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#           (1): Permute()
#           (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=128, out_features=512, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=512, out_features=128, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.017142857142857144, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#           (1): Permute()
#           (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=128, out_features=512, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=512, out_features=128, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.03428571428571429, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): LayerNorm2d((128,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(128, 256, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (3): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#           (1): Permute()
#           (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=256, out_features=1024, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1024, out_features=256, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.05142857142857142, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#           (1): Permute()
#           (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=256, out_features=1024, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1024, out_features=256, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.06857142857142857, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#           (1): Permute()
#           (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=256, out_features=1024, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=1024, out_features=256, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.08571428571428572, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): LayerNorm2d((256,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(256, 512, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (5): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.10285714285714284, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.12000000000000001, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.13714285714285715, mode=row)
#       )
#       (3): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.15428571428571428, mode=row)
#       )
#       (4): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.17142857142857143, mode=row)
#       )
#       (5): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.18857142857142856, mode=row)
#       )
#       (6): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.20571428571428568, mode=row)
#       )
#       (7): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.22285714285714286, mode=row)
#       )
#       (8): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.24000000000000002, mode=row)
#       )
#       (9): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2571428571428571, mode=row)
#       )
#       (10): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2742857142857143, mode=row)
#       )
#       (11): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.2914285714285714, mode=row)
#       )
#       (12): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.30857142857142855, mode=row)
#       )
#       (13): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.32571428571428573, mode=row)
#       )
#       (14): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.34285714285714286, mode=row)
#       )
#       (15): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.36, mode=row)
#       )
#       (16): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.3771428571428571, mode=row)
#       )
#       (17): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.39428571428571424, mode=row)
#       )
#       (18): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.41142857142857137, mode=row)
#       )
#       (19): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.42857142857142855, mode=row)
#       )
#       (20): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.44571428571428573, mode=row)
#       )
#       (21): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.46285714285714286, mode=row)
#       )
#       (22): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.48000000000000004, mode=row)
#       )
#       (23): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.4971428571428571, mode=row)
#       )
#       (24): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5142857142857142, mode=row)
#       )
#       (25): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5314285714285714, mode=row)
#       )
#       (26): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#           (1): Permute()
#           (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=512, out_features=2048, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=2048, out_features=512, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5485714285714286, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): LayerNorm2d((512,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(512, 1024, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (7): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#           (1): Permute()
#           (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1024, out_features=4096, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=4096, out_features=1024, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5657142857142857, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#           (1): Permute()
#           (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1024, out_features=4096, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=4096, out_features=1024, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.5828571428571429, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#           (1): Permute()
#           (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=1024, out_features=4096, bias=True)
#           (4): GELU(approximate='none')
#           (5): Linear(in_features=4096, out_features=1024, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.6, mode=row)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): LayerNorm2d((1024,), eps=1e-06, elementwise_affine=True)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=1024, out_features=1000, bias=True)
#   )
# ) completed in 5456m 30s

# %% [markdown]
# ## Model comparison
#
# In this section, we compare the final validation accuracy of the ConvNeXt model across the different datasets (full image vs. bounding box) by reading the cached JSON results and comparing them with other baseline models.

# %%
model_name = args.model_name
for dataset in fovea.params.all_datasets:
    results = fovea.pd.read_json(args.data_cache / f'21_model_name={model_name}_dataset={dataset}.json')
    print(model_name, dataset, results.tail(1)['acc_val'])
# Out:
# convnext_base full 39    0.830389
# Name: acc_val, dtype: float64
# convnext_base bbox 39    0.821992
# Name: acc_val, dtype: float64

# %%
results
# Out:
#     epoch  i_image  total_image  loss_train  acc_train   acc_val  \
# 0       0   615232       615232    0.712810   0.840844  0.808174
# 1       1   615232      1230464    0.580657   0.853873  0.811493
# 2       2   615232      1845696    0.551687   0.858670  0.813917
# 3       3   615232      2460928    0.534954   0.861644  0.815123
# 4       4   615232      3076160    0.522227   0.864081  0.816192
# 5       5   615232      3691392    0.513325   0.865491  0.816801
# 6       6   615232      4306624    0.504002   0.867679  0.817485
# 7       7   615232      4921856    0.497807   0.868651  0.818442
# 8       8   615232      5537088    0.490457   0.870359  0.818815
# 9       9   615232      6152320    0.484779   0.871086  0.818976
# 10     10   615168      6767488    0.482613   0.871863  0.819429
# 11     11   615168      7382656    0.474125   0.873683  0.819740
# 12     12   615168      7997824    0.473246   0.873730  0.820337
# 13     13   615168      8612992    0.470893   0.874701  0.820288
# 14     14   615168      9228160    0.465876   0.875467  0.821071
# 15     15   615168      9843328    0.463000   0.875860  0.821233
# 16     16   615168     10458496    0.461613   0.876808  0.821134
# 17     17   615168     11073664    0.458462   0.877017  0.821270
# 18     18   615168     11688832    0.457714   0.877409  0.821395
# 19     19   615168     12304000    0.455028   0.878155  0.821569
# 20     20   615168     12919168    0.454825   0.877507  0.821333
# 21     21   615168     13534336    0.452734   0.878344  0.821768
# 22     22   615168     14149504    0.451489   0.878753  0.821818
# 23     23   615168     14764672    0.451303   0.878488  0.821693
# 24     24   615168     15379840    0.450525   0.878718  0.821905
# 25     25   615168     15995008    0.450194   0.879056  0.821756
# 26     26   615168     16610176    0.450177   0.879181  0.821681
# 27     27   615168     17225344    0.447704   0.879444  0.821594
# 28     28   615168     17840512    0.447126   0.879496  0.821644
# 29     29   615168     18455680    0.451113   0.878929  0.821606
# 30     30   615168     19070848    0.449675   0.879451  0.821619
# 31     31   615168     19686016    0.446715   0.879690  0.821581
# 32     32   615168     20301184    0.451069   0.878573  0.821656
# 33     33   615168     20916352    0.450871   0.878981  0.821656
# 34     34   615168     21531520    0.449729   0.879079  0.821731
# 35     35   615168     22146688    0.449105   0.879087  0.821955
# 36     36   615168     22761856    0.447500   0.879027  0.821830
# 37     37   615168     23377024    0.447815   0.879618  0.821905
# 38     38   615168     23992192    0.447923   0.879675  0.822029
# 39     39   615168     24607360    0.445374   0.880464  0.821992
#
#              time
# 0     3676.018069
# 1     7344.292845
# 2    11027.639507
# 3    14702.239971
# 4    18384.915866
# 5    22058.198824
# 6    25744.507159
# 7    29419.848765
# 8    33103.574319
# 9    36780.086257
# 10   10816.925981
# 11   21692.683391
# 12   33403.864216
# 13   46472.845459
# 14   57370.504331
# 15   68186.744889
# 16   78953.743692
# 17   89738.993969
# 18  101099.245963
# 19  112113.684350
# 20  122835.215469
# 21  133604.553061
# 22  144377.195242
# 23  155118.810601
# 24  165893.421928
# 25  176673.230066
# 26  187451.832208
# 27  198229.607511
# 28  208961.244514
# 29  219722.690368
# 30  230501.668548
# 31  241278.591054
# 32  252057.958489
# 33  262829.310067
# 34  273572.642877
# 35  284340.082144
# 36  295116.147319
# 37  305850.474715
# 38  316599.584082
# 39  327388.439482

# %%
results_13 = fovea.pd.read_json(args.data_cache / '13_model_comparison.json')
results_13
# Out:
#    model_name  do_mask dataset  accuracy  wall_clock_time  total_parameters  \
# 0    resnet18     True    full  0.514864         0.002919          11689512
# 1    resnet50     True    full  0.789844         0.003330          25557032
# 2   resnet101     True    full  0.801082         0.003886          44549160
# 3    resnet18     True    bbox  0.463314         0.003615          11689512
# 4    resnet50     True    bbox  0.725555         0.003712          25557032
# 5   resnet101     True    bbox  0.755586         0.004802          44549160
# 6    resnet18    False    full  0.692328         0.003309          11689512
# 7    resnet50    False    full  0.807232         0.004278          25557032
# 8   resnet101    False    full  0.817248         0.005086          44549160
# 9    resnet18    False    bbox  0.651336         0.003749          11689512
# 10   resnet50    False    bbox  0.749390         0.004347          25557032
# 11  resnet101    False    bbox  0.775838         0.004138          44549160
#
#     trainable_parameters  total_layers
# 0               11689512            68
# 1               25557032           151
# 2               44549160           287
# 3               11689512            68
# 4               25557032           151
# 5               44549160           287
# 6               11689512            68
# 7               25557032           151
# 8               44549160           287
# 9               11689512            68
# 10              25557032           151
# 11              44549160           287

# %% [markdown]
# ## Plot learning evolution
#
# This section visualizes the learning process by plotting the training and validation accuracy as a function of the total number of images processed. A rolling mean is applied to smooth the accuracy curves for better visualization.

# %%
fig, ax = fovea.plt.subplots()
for dataset in ['bbox']: # fovea.params.all_datasets:
    color = 'r'
    lw = 1

    name = f'21_model_name={model_name}_dataset={dataset}'
    model_filename, json_filename = fovea.do_learning(args, dataset, name)

    df_train = fovea.pd.read_json(json_filename, orient='records')

    df_train_roll = df_train.rolling(window=5, min_periods=1, center=False).mean()
    ax = df_train_roll.plot(x='total_image', y='acc_train', 
                        c=color, ls='dashed', lw=lw,
                        grid=True, ax=ax, label='TRAIN: ' + args.model_name)    
    ax = df_train_roll.plot(x='total_image', y='acc_val', 
                        c=color, lw=lw,
                        grid=True, ax=ax, label='VAL: ' + args.model_name)
# Out:
# Load JSON from pre-trained resnet cached_data/21_model_name=convnext_base_dataset=bbox.json
# cached_data/21_model_name=convnext_base_dataset=bbox.pth: latest accuracy = 0.822

# %%
df_train
# Out:
#     epoch  i_image  total_image  loss_train  acc_train   acc_val  \
# 0       0   615232       615232    0.712810   0.840844  0.808174
# 1       1   615232      1230464    0.580657   0.853873  0.811493
# 2       2   615232      1845696    0.551687   0.858670  0.813917
# 3       3   615232      2460928    0.534954   0.861644  0.815123
# 4       4   615232      3076160    0.522227   0.864081  0.816192
# 5       5   615232      3691392    0.513325   0.865491  0.816801
# 6       6   615232      4306624    0.504002   0.867679  0.817485
# 7       7   615232      4921856    0.497807   0.868651  0.818442
# 8       8   615232      5537088    0.490457   0.870359  0.818815
# 9       9   615232      6152320    0.484779   0.871086  0.818976
# 10     10   615168      6767488    0.482613   0.871863  0.819429
# 11     11   615168      7382656    0.474125   0.873683  0.819740
# 12     12   615168      7997824    0.473246   0.873730  0.820337
# 13     13   615168      8612992    0.470893   0.874701  0.820288
# 14     14   615168      9228160    0.465876   0.875467  0.821071
# 15     15   615168      9843328    0.463000   0.875860  0.821233
# 16     16   615168     10458496    0.461613   0.876808  0.821134
# 17     17   615168     11073664    0.458462   0.877017  0.821270
# 18     18   615168     11688832    0.457714   0.877409  0.821395
# 19     19   615168     12304000    0.455028   0.878155  0.821569
# 20     20   615168     12919168    0.454825   0.877507  0.821333
# 21     21   615168     13534336    0.452734   0.878344  0.821768
# 22     22   615168     14149504    0.451489   0.878753  0.821818
# 23     23   615168     14764672    0.451303   0.878488  0.821693
# 24     24   615168     15379840    0.450525   0.878718  0.821905
# 25     25   615168     15995008    0.450194   0.879056  0.821756
# 26     26   615168     16610176    0.450177   0.879181  0.821681
# 27     27   615168     17225344    0.447704   0.879444  0.821594
# 28     28   615168     17840512    0.447126   0.879496  0.821644
# 29     29   615168     18455680    0.451113   0.878929  0.821606
# 30     30   615168     19070848    0.449675   0.879451  0.821619
# 31     31   615168     19686016    0.446715   0.879690  0.821581
# 32     32   615168     20301184    0.451069   0.878573  0.821656
# 33     33   615168     20916352    0.450871   0.878981  0.821656
# 34     34   615168     21531520    0.449729   0.879079  0.821731
# 35     35   615168     22146688    0.449105   0.879087  0.821955
# 36     36   615168     22761856    0.447500   0.879027  0.821830
# 37     37   615168     23377024    0.447815   0.879618  0.821905
# 38     38   615168     23992192    0.447923   0.879675  0.822029
# 39     39   615168     24607360    0.445374   0.880464  0.821992
#
#              time
# 0     3676.018069
# 1     7344.292845
# 2    11027.639507
# 3    14702.239971
# 4    18384.915866
# 5    22058.198824
# 6    25744.507159
# 7    29419.848765
# 8    33103.574319
# 9    36780.086257
# 10   10816.925981
# 11   21692.683391
# 12   33403.864216
# 13   46472.845459
# 14   57370.504331
# 15   68186.744889
# 16   78953.743692
# 17   89738.993969
# 18  101099.245963
# 19  112113.684350
# 20  122835.215469
# 21  133604.553061
# 22  144377.195242
# 23  155118.810601
# 24  165893.421928
# 25  176673.230066
# 26  187451.832208
# 27  198229.607511
# 28  208961.244514
# 29  219722.690368
# 30  230501.668548
# 31  241278.591054
# 32  252057.958489
# 33  262829.310067
# 34  273572.642877
# 35  284340.082144
# 36  295116.147319
# 37  305850.474715
# 38  316599.584082
# 39  327388.439482
