# %% [markdown]
# In this script, we evaluate how the data loading configuration (DataLoader) affects the real-world inference time (Wall Clock Time).
#
# We will test three key parameters:
# 1. Batch size (`batch_size`): to see the effect of vectorization.
# 2. Number of workers (`num_workers`): to optimize parallel image loading.
# 3. Prefetch factor (`prefetch_factor`): to reduce waiting times between batches.

# %%
import retinoto_py as fovea
subset_factor = 2
args = fovea.Params(subset_factor=subset_factor)
args
# Out:
# Params(batch_size=32, num_workers=4, prefetch_factor=0, image_size=224, grid_size_ecc=161, grid_size_ang=309, do_mask=False, do_fovea=True, use_hexagonal_grid=True, rs_min=-3.5, rs_max=0.7, angle_start=-5.235987755982989, angle_margin=0.010166966516471823, mode='bilinear', padding_mode='zeros', model_name='convnext_base', num_epochs=100, subset_factor=2, optimizer_name='adamw', loss_name='CrossEntropyLoss', base_lr=1e-06, final_lr=1e-09, num_warmup_epochs=20, delta1=0.3, delta2=0.002, weight_decay=0.0001, label_smoothing=0.0005, do_full_training=True, do_augment=True, augment_proba=0.85, stochastic_depth_prob=0.6, seed=1998, shuffle=True, verbose=False)

# %% [markdown]
# # testing the default model on the validation dataset

# %%
# 2. Initialize the a baseline model and dataset to conduct benchmarks on
VAL_DATA_DIR = args.DATAROOT / 'Imagenet_bbox' / 'val'
val_dataset = fovea.get_dataset(args, VAL_DATA_DIR)
fovea.get_loader(args, val_dataset)
model = fovea.load_model(args)
model.eval()
print(f"Model {args.model_name} loaded.")
# Out:
# Model convnext_base loaded.

# %% [markdown]
# # testing the role of batch_size on Wall Clock Time

# %%
# 3. Benchmark the impact of `batch_size` on Wall Clock Time
var = 'batch_size'
fname = f'12_{var}'
json_filename = args.data_cache / (fname + '.json')

# %rm {json_filename}  # FORCING RECOMPUTE

if json_filename.exists():
    results = fovea.pd.read_json(json_filename)
else:
    all_results = []
    # Test various batch sizes from 2 to 1024 to find the saturation point
    pbar = fovea.tqdm([2, 4, 8, 16, 32, 64, 128, 256, 512, 1024], desc=f'Testing {var}')
    val_dataset = fovea.get_dataset(args, VAL_DATA_DIR)

    for value in pbar:
        pbar.set_postfix({var: value})
        args = fovea.Params(batch_size=value, subset_factor=subset_factor)
        val_loader = fovea.get_loader(args, val_dataset)
        model = fovea.load_model(args)
        tic = fovea.time.time()
        accuracy = fovea.get_validation_accuracy(args, model, val_loader)
        toc = fovea.time.time()
        this_result = { var: value,
                        'accuracy': accuracy,
                        'wall_clock_time': (toc-tic)/len(val_dataset),
                        }
        all_results.append(this_result)
    results = fovea.pd.DataFrame(all_results)
    results.to_json(json_filename, orient='records', indent=2)
# Out:
# ...
# Evaluating convnext_base:   0%|          | 0/39 [00:11<?, ?it/s]

# %%
results.T

# %%
def plot_results(results, var, xlog=True):
    # --- Plot 1: Wall Clock Time (in Blue) ---
    results['wall_clock_time_ms'] = results['wall_clock_time']*1000
    # Assign a label directly for legend creation
    ax = fovea.sns.lineplot(
        data=results,
        x=var,
        y='wall_clock_time_ms',
        color='blue',                  # Set color to blue
        marker='o',
        markersize=8,
        alpha=0.6,
        lw=2,
        label='Wall Clock Time (ms/image)',   # Legend label for this line
        legend=False
    )

    # --- Plot 2: Accuracy (in Orange) ---
    ax2 = ax.twinx()
    fovea.sns.lineplot(
        data=results,
        x=var,
        y='accuracy',
        color='orange',                # Set color to orange
        marker='D',                    # Different marker for distinction
        markersize=8,
        alpha=0.6,
        lw=2,
        ax=ax2,                        # Plot on the secondary y-axis
        label='Accuracy',               # Legend label for this line
        legend=False
    )

    # --- Final Touches ---
    # Set log scale for the x-axis
    if xlog: ax.set_xscale('log')

    # Set axis labels and title
    ax.set_xlabel(f'{var}{" (log scale)" if xlog else ""}')
    ax.set_ylabel('Wall Clock Time (s)', color='blue')
    ax2.set_ylabel('Accuracy', color='orange')

    # Match the tick colors to the lines for clarity
    ax.tick_params(axis='y', labelcolor='blue')
    ax2.tick_params(axis='y', labelcolor='orange')

    # Set the main title
    ax.set_title(f'Model Performance vs. {var}')

    # Create a single, unified legend
    # Get handles and labels from both axes
    h1, l1 = ax.get_legend_handles_labels()
    h2, l2 = ax2.get_legend_handles_labels()
    # Combine them and place the legend
    ax.legend('acc', 'time', loc='upper center', bbox_to_anchor=(0.25, 0.95), ncol=2)
    # ax.legend(h1 + h2, l1 + l2, loc='upper center', bbox_to_anchor=(0.25, 0.95), ncol=2)


    # plt.tight_layout()
    # Adjust layout to make space for the legend below the plot
    fovea.plt.subplots_adjust(bottom=0.05) 
    return ax, ax2

ax, ax2 = plot_results(results, var)

# %%
fovea.savefig(ax.get_figure(), name=fname, figures_folder=args.figures_folder)

# %% [markdown]
# # testing the role of `num_workers` on Wall Clock Time

# %%
args.num_workers

# %%
# 4. Benchmark the impact of `num_workers` on Wall Clock Time
var = 'num_workers'
fname = f'12_{var}'
json_filename = args.data_cache / (fname + '.json')

# %rm {json_filename}  # FORCING RECOMPUTE

if json_filename.exists():
    results = fovea.pd.read_json(json_filename)
else:
    all_results = []
    pbar = fovea.tqdm([0, 1, 2, 4, 8, 16], desc=f'Testing {var}')
    val_dataset = fovea.get_dataset(args, VAL_DATA_DIR)

    for value in pbar:
        pbar.set_postfix({var: value})
        args = fovea.Params(num_workers=value, 
                            prefetch_factor=None if value==0 else args.prefetch_factor,
                            subset_factor=subset_factor)
        val_loader = fovea.get_loader(args, val_dataset)
        model = fovea.load_model(args)
        tic = fovea.time.time()
        accuracy = fovea.get_validation_accuracy(args, model, val_loader)
        toc = fovea.time.time()
        this_result = {         
                        var: value,
                        'accuracy': accuracy,
                        'wall_clock_time': (toc-tic)/len(val_dataset),
                        }
        all_results.append(this_result)
    results = fovea.pd.DataFrame(all_results)
    results.to_json(json_filename, orient='records', indent=2)

# %%
results.T

# %%
ax, ax2 = plot_results(results, var, xlog=False)

# %%
fovea.savefig(ax.get_figure(), name=fname, figures_folder=args.figures_folder)

# %% [markdown]
# # testing the role of `prefetch_factor` on Wall Clock Time

# %%
args.prefetch_factor

# %%
# 5. Benchmark the impact of `prefetch_factor` on Wall Clock Time
var = 'prefetch_factor'
fname = f'12_{var}'
json_filename = args.data_cache / (fname + '.json')

# %rm {json_filename}  # FORCING RECOMPUTE

if json_filename.exists():
    results = fovea.pd.read_json(json_filename)
else:
    all_results = []
    pbar = fovea.tqdm([0, 1, 2, 4, 6, 8, 10], desc=var)
    val_dataset = fovea.get_dataset(args, VAL_DATA_DIR)

    for value in pbar:
        pbar.set_postfix({var: value})
        args = fovea.Params(num_workers=args.num_workers, prefetch_factor=value, subset_factor=subset_factor)
        val_loader = fovea.get_loader(args, val_dataset)
        model = fovea.load_model(args)
        tic = fovea.time.time()
        accuracy = fovea.get_validation_accuracy(args, model, val_loader)
        toc = fovea.time.time()
        this_result = {         
                        var: value,
                        'accuracy': accuracy,
                        'wall_clock_time': (toc-tic)/len(val_dataset),
                        }
        all_results.append(this_result)
    results = fovea.pd.DataFrame(all_results)
    results.to_json(json_filename, orient='records', indent=2)

# %%
results.T

# %%
ax, ax2 = plot_results(results, var, xlog=False)

# %%
fovea.savefig(ax.get_figure(), name=fname, figures_folder=args.figures_folder)
